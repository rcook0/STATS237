# %% [markdown]
# # Monte Carlo Variance Reduction
#
# Arithmetic Asian with geometric control variate + antithetic sampling.

# %%
from stats237_quantlib.mc.asian import arithmetic_asian_call_mc

S0=100; K=100; r=0.02; q=0.0; sigma=0.2; T=1.0
res = arithmetic_asian_call_mc(S0,K,r,q,sigma,T, n_paths=20000, n_steps=252, seed=123, antithetic=True, control_variate=True)
res
