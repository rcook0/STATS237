# %% [markdown]
# # Black–Scholes + Greeks
#
# Demonstrates closed-form pricing, Greeks, and implied volatility inversion.

# %%
from stats237_quantlib.pricing.black_scholes import bs_call_price, bs_put_price, bs_greeks, implied_vol

S=100; K=105; r=0.02; q=0.0; sigma=0.25; T=0.5

c = bs_call_price(S,K,r,q,sigma,T)
p = bs_put_price(S,K,r,q,sigma,T)
g = bs_greeks(S,K,r,q,sigma,T)
iv = implied_vol(price=c, S=S, K=K, r=r, q=q, T=T, option_type='call')

(c, p, g, iv)
